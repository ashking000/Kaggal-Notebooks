# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HF_TOKEN")

# %%
import os
import subprocess
import time
from pyngrok import ngrok

# --- CONFIGURATION ---
PORT = 8889
NGROK_TOKEN = "YOUR_NGROK_AUTHTOKEN_HERE" 

# 1. FIX KAGGLE ENVIRONMENT
# Stops Kaggle from crashing when a background server tries to use plotting
os.environ["MPLBACKEND"] = "agg"

# 2. CLEANUP
print("Cleaning up old processes...")
# !fuser -k {PORT}/tcp > /dev/null 2>&1
# !pkill -f "unsloth"
# !pkill -f "ngrok"
ngrok.kill()

# 3. OFFICIAL INSTALLATION
# This is the step that fixes the "Run install.sh first" error
if not os.path.exists(os.path.expanduser("~/.local/bin/unsloth")):
    print("Running official Unsloth installation script...")
    # !curl -fsSL https://unsloth.ai/install.sh | sh
else:
    print("Unsloth Studio is already installed.")

# 4. START STUDIO
# Point directly to the binary installed by the script
UNSLOTH_BIN = os.path.expanduser("~/.local/bin/unsloth")
print(f"Launching Unsloth Studio on port {PORT}...")

# Run as a background process
os.system(f"nohup {UNSLOTH_BIN} studio --host 0.0.0.0 --port {PORT} > studio_log.txt 2>&1 &")

# 5. WAIT FOR PORT TO OPEN
print("Waiting for Studio to wake up...")
time.sleep(15) 

# 6. START NGROK
print("Opening Ngrok Tunnel...")
ngrok.set_auth_token(NGROK_TOKEN)
public_url = ngrok.connect(PORT).public_url

print("\n" + "="*50)
print(f"SUCCESS! STUDIO IS LIVE")
print(f"Public URL: {public_url}")
print("="*50)
print("1. Open the URL above.")
print("2. Set a password if prompted (first-time use).")
print("3. Go to 'Models' and load your Hermes GGUF model.")
print(f"4. Point your PC Hermes setup to: {public_url}/v1")
print("="*50)

# Keep the cell alive
try:
    while True:
        time.sleep(10)
except KeyboardInterrupt:
    print("Stopping...")
# Out:
# Cleaning up old processes...
# Running official Unsloth installation script...
#
#   🦥 Unsloth Studio Installer
#   ────────────────────────────────────────────────────
#
#   platform       linux
#   deps           all system dependencies found
#   venv           creating Python 3.13 virtual environment
#                  /root/.unsloth/studio/unsloth_studio
#   venv           using environment
#                  /root/.unsloth/studio/unsloth_studio
#                  installing PyTorch (https://download.pytorch.org/whl/cu130)...
#                  installing unsloth (this may take a few minutes)...
#   setup          running unsloth studio update...
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#   frontend       up to date
#   deps           [====================] 13/13  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
# ...

# %%
import os
import subprocess
import time
from pyngrok import ngrok

# --- CONFIGURATION ---
PORT = 8889
NGROK_TOKEN = "3CtRVhR3XWdCro0Fw1kBQG8t9yf_58QcKTWVxp8kYe4yWRniu" # Make sure this is your real token!

# 1. ADD UNSLOTH TO PATH
# The installer put it in ~/.local/bin, but we need to tell Python where that is
os.environ["PATH"] += os.pathsep + os.path.expanduser("~/.local/bin")

# 2. CLEANUP
print("Cleaning up ghost processes...")
# !fuser -k {PORT}/tcp > /dev/null 2>&1
# !pkill -f "unsloth"
# !pkill -f "ngrok"
ngrok.kill()

# 3. LAUNCH STUDIO
print(f"Starting Unsloth Studio on port {PORT}...")
# We use 'nohup' so it stays alive in the background
os.system(f"nohup unsloth studio --host 0.0.0.0 --port {PORT} > studio_log.txt 2>&1 &")

# 4. WAIT FOR INITIALIZATION
print("Waiting 15 seconds for the server to spin up...")
time.sleep(15)

# 5. START NGROK
print("Opening the tunnel to your PC...")
ngrok.set_auth_token(NGROK_TOKEN)
public_url = ngrok.connect(PORT).public_url

print("\n" + "█"*50)
print(f"  STUDIO IS NOW LIVE!")
print(f"  URL: {public_url}")
print("  █" + "█"*48)
print("\nSTEPS TO CONNECT HERMES:")
print(f"1. Open the URL above in your browser.")
print(f"2. Go to 'Models' inside the Studio and load 'Hermes-3-Llama-3.1-8B-GGUF'.")
print(f"3. On your PC Hermes setup, use this Base URL: {public_url}/v1")
print(f"4. Use the API Key found in Studio 'Settings'.")
print("="*50)

# Keep alive loop
try:
    while True:
        time.sleep(10)
except KeyboardInterrupt:
    print("Shutting down tunnel...")
# Out:
# Cleaning up ghost processes...
# Starting Unsloth Studio on port 8889...
# Waiting 15 seconds for the server to spin up...
# Opening the tunnel to your PC...
#
# ██████████████████████████████████████████████████
#   STUDIO IS NOW LIVE!
#   URL: https://countless-irrigate-vitality.ngrok-free.dev
#   █████████████████████████████████████████████████
#
# STEPS TO CONNECT HERMES:
# 1. Open the URL above in your browser.
# 2. Go to 'Models' inside the Studio and load 'Hermes-3-Llama-3.1-8B-GGUF'.
# 3. On your PC Hermes setup, use this Base URL: https://countless-irrigate-vitality.ngrok-free.dev/v1
# 4. Use the API Key found in Studio 'Settings'.
# ...
