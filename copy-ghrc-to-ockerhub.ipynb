# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !apt-get update -y && apt-get install -y skopeo
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [93.4 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,915 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,004 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [61.6 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.2 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,292 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,341 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,602 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:23 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,010 kB]
# Get:24 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.9 kB]
# Fetched 39.5 MB in 3s (12.4 MB/s)
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
#
#
# The following additional packages will be installed:
#   golang-github-containers-common golang-github-containers-image libgpgme11
# The following NEW packages will be installed:
#   golang-github-containers-common golang-github-containers-image libgpgme11
#   skopeo
# 0 upgraded, 4 newly installed, 0 to remove and 208 not upgraded.
# Need to get 5,283 kB of archives.
# After this operation, 16.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 golang-github-containers-image all 5.16.0-3 [29.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 golang-github-containers-common all 0.44.4+ds1-1 [28.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.2 [136 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 skopeo amd64 1.4.1+ds1-1ubuntu0.1 [5,090 kB]
# Fetched 5,283 kB in 0s (28.7 MB/s)
# Selecting previously unselected package golang-github-containers-image.
# (Reading database ... 120314 files and directories currently installed.)
# Preparing to unpack .../golang-github-containers-image_5.16.0-3_all.deb ...
# Unpacking golang-github-containers-image (5.16.0-3) ...
# Selecting previously unselected package golang-github-containers-common.
# Preparing to unpack .../golang-github-containers-common_0.44.4+ds1-1_all.deb ...
# Unpacking golang-github-containers-common (0.44.4+ds1-1) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package skopeo.
# Preparing to unpack .../skopeo_1.4.1+ds1-1ubuntu0.1_amd64.deb ...
# Unpacking skopeo (1.4.1+ds1-1ubuntu0.1) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up golang-github-containers-image (5.16.0-3) ...
# Setting up golang-github-containers-common (0.44.4+ds1-1) ...
# Setting up skopeo (1.4.1+ds1-1ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link

# %%
# !skopeo --version
# Out:
# skopeo version 1.4.1

# %%
# !skopeo copy \
  docker://ghcr.io/ashking000/ollama-huihui-q5:latest\
  --dest-creds="ashking00:dckr_pat_BmSzlwTCA8aVZXvFuyGxucyr_no" \
  docker://docker.io/ashking00/ollama-hui:v1
# Out:
# Getting image source signatures
# Copying blob d108cd031821 [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f [--------------------------------------] 0.0b / 0.0b
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [-------------------------------------] 0.0b / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [-------------------------------------] 0.0b / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 302.7KiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [-----------------------------------] 2.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [-----------------------------------] 4.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [-----------------------------------] 9.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 15.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 19.5MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 23.6MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 28.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 32.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 36.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 40.3MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 44.9MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 48.9MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 53.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 57.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 62.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 66.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 70.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 75.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 79.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 84.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 88.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 92.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [----------------------------------] 96.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 101.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 105.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 110.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 114.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 118.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 123.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 126.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 130.4MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 134.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 137.4MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 141.4MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 144.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 148.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 152.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 156.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 159.5MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 163.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 166.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 170.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 173.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 177.4MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 180.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 184.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 188.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 192.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 195.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 199.7MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 202.9MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 206.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 210.2MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 213.6MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 217.5MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 220.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 224.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 228.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 232.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 235.9MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 239.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 243.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 247.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 250.3MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 254.3MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 257.6MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 261.2MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 264.8MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 268.1MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 272.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d [---------------------------------] 276.0MiB / 22.9GiB
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# ...
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying blob d108cd031821 skipped: already exists
# Copying blob 156f40b3ff76 skipped: already exists
# Copying blob b40150c1c271 skipped: already exists
# Copying blob 4446d4bc9744 skipped: already exists
# Copying blob b3c30302e2fa skipped: already exists
# Copying blob 59afcb5f254f skipped: already exists
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob f9e1bcbb745a skipped: already exists
# Copying blob 40ce83b38f2f skipped: already exists
# Copying blob cac6b78aed8d done
# Copying config f26fe274b4 [--------------------------------------] 0.0b / 6.4KiB
# Copying config f26fe274b4 [--------------------------------------] 0.0b / 6.4KiB
# Copying config f26fe274b4 [====================================] 6.4KiB / 6.4KiB
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Copying config f26fe274b4 done
# Writing manifest to image destination
# Storing signatures
